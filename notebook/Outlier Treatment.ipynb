# %%
import pandas as pd
import numpy as np
from typing import List
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../input/train.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
missing_col = df.columns[df.isnull().any()]
missing_col
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Self_Employed', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
def handle_missing(df: pd.DataFrame, missing_col: List[str]) -> pd.DataFrame:
    """
    df: pandas dataframe
    missing_col: List of columns having missing values
    """
    for c in missing_col:
        if c in df.columns[df.dtypes == 'object']:
            df.loc[:,c] = df.loc[:, c].astype(str).fillna(df.loc[:,c].mode())
        else:
            df[c] = df[c].fillna(df[c].mean())
    return df

# %%
handle_missing(df= df, missing_col=missing_col)

# %%
df.loc[:, "Gender"].mode()

# %%
from statistics import mode
import pandas as pd
import numpy as np
from typing import List, Union


class Exploratory:
    def __init__(self, dataframe: pd.DataFrame) -> None:
        self.df = dataframe
        self.missing_col: List[str] = self.df.columns[self.df.isnull().any()]


    def missing_na(self) -> pd.DataFrame:
        for c in self.missing_col:
            if c in list(set(self.df.columns[self.df.dtypes=="object"])):
                self.df.loc[c] = self.df.loc[:, c].astype(str).fillna(self.df.loc[:, c].mode())
            elif c in list(set(self.df.columns[(self.df.dtypes=="float")|(self.df.dtypes=="int")])):
                self.df[c] = self.df.loc[:, c].fillna(self.df.loc[:, c].mean())
            else:
                raise Exception("Something went wrong!!")
        print(self.df.isnull().sum())
        return self.df
    

    def outlier_detection(self) -> List[str]:
        outlier : List[Union[int, float]]
        for c in self.df:
            col_mean = self.df[c].mean()
            std_dev = np.std(self.df[c])
            z = (self.df[c] - col_mean)/std_dev
            if (z > col_mean).any():
                outlier.append(c)
            print("mean of {} is {} and standard Deviation is {} ".format(c, col_mean,std_dev))    
            print("outlier in {}".format(c), outlier)
        return outlier

# %%
Exploratory(dataframe=df).missing_na()
# Out:
# Loan_ID               4
# Gender               14
# Married               5
# Dependents           18
# Education             4
# Self_Employed        36
# ApplicantIncome       4
# CoapplicantIncome     4
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         4
# Loan_Status           4
# dtype: int64
#                 Loan_ID  Gender Married Dependents     Education  \
# 0              LP001002    Male      No          0      Graduate
# 1              LP001003    Male     Yes          1      Graduate
# 2              LP001005    Male     Yes          0      Graduate
# 3              LP001006    Male     Yes          0  Not Graduate
# 4              LP001008    Male      No          0      Graduate
# ...                 ...     ...     ...        ...           ...
# 613            LP002990  Female      No          0      Graduate
# Gender              NaN     NaN     NaN        NaN           NaN
# ...

# %%
Exploratory(dataframe=df).outlier_detection()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 Exploratory(dataframe=df).outlier_detection()
#
# Input In [5], in Exploratory.outlier_detection(self)
#      26 outlier : List[Union[int, float]]
#      27 for c in self.df:
# ---> 28     col_mean = self.df[c].mean()
#      29     std_dev = np.std(self.df[c])
#      30     z = (self.df[c] - col_mean)/std_dev
#
# File /media/harendra/DATA/Loan_Prediction/env/lib/python3.10/site-packages/pandas/core/generic.py:11119, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11101 @doc(
#   11102     _num_doc,
#   11103     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11117     **kwargs,
#   11118 ):
# > 11119     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# ...
